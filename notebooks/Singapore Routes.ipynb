# %%
from utils import make_route, parse_gpx, plot_gpx

# %%
start = (1.3096544821614164, 103.89624655769467)
stop = (1.2869149, 103.8547688)

shortest_gpx = "../routes/Merlion - Shortest Route.gpx"
custom_gpx = "../routes/Merlion - Custom.gpx"

make_route(start, stop, "shortest", shortest_gpx)
make_route(start, stop, "custom", custom_gpx)

shortest_df = parse_gpx(shortest_gpx)
custom_df = parse_gpx(custom_gpx)

plot_gpx(shortest_df, custom_df)
# Out:
# shortest : 6.2km
# custom : 8.2km

# %%
start = (1.3096544821614164, 103.89624655769467)
stop = (1.2918406, 103.8476213)

shortest_gpx = "../routes/Fort Canning Park - Shortest Route.gpx"
custom_gpx = "../routes/Fort Canning Park - Custom.gpx"

make_route(start, stop, "shortest", shortest_gpx)
make_route(start, stop, "custom", custom_gpx)

shortest_df = parse_gpx(shortest_gpx)
custom_df = parse_gpx(custom_gpx)

plot_gpx(shortest_df, custom_df)
# Out:
# shortest : 6.5km
# custom : 7.4km

# %%
start = (1.3096544821614164, 103.89624655769467)
stop = (1.3412162, 103.8340349)

shortest_gpx = "../routes/MacRitchie Reservoir - Shortest Route.gpx"
custom_gpx = "../routes/MacRitchie Reservoir - Custom.gpx"

make_route(start, stop, "shortest", shortest_gpx)
make_route(start, stop, "custom", custom_gpx)

shortest_df = parse_gpx(shortest_gpx)
custom_df = parse_gpx(custom_gpx)

plot_gpx(shortest_df, custom_df)
# Out:
# shortest : 9.4km
# custom : 11.5km

# %%
start = (1.3096544821614164, 103.89624655769467)
stop = (1.2718742, 103.8192125)

shortest_gpx = "../routes/Mount Faber Park - Shortest Route.gpx"
custom_gpx = "../routes/Mount Faber Park - Custom.gpx"

make_route(start, stop, "shortest", shortest_gpx)
make_route(start, stop, "custom", custom_gpx)

shortest_df = parse_gpx(shortest_gpx)
custom_df = parse_gpx(custom_gpx)

plot_gpx(shortest_df, custom_df)
# Out:
# shortest : 11.0km
# custom : 12.1km

# %%
start = (1.3096544821614164, 103.89624655769467)
stop = (103.9245499,1.3413025)

shortest_gpx = "../routes/Mount Faber Park - Shortest Route.gpx"
custom_gpx = "../routes/Mount Faber Park - Custom.gpx"

make_route(start, stop, "shortest", shortest_gpx)
make_route(start, stop, "custom", custom_gpx)

shortest_df = parse_gpx(shortest_gpx)
custom_df = parse_gpx(custom_gpx)

plot_gpx(shortest_df, custom_df)
